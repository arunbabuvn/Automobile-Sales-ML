# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('historical_automobile_sales_modified.csv')
df
# Out:
#              Date  Year Month  Recession  Consumer_Confidence  \
# 0       1/31/1980  1980   Jan          1           108.240000
# 1       2/29/1980  1980   Feb          1            98.750000
# 2       3/31/1980  1980   Mar          1           107.480000
# 3       4/30/1980  1980   Apr          1           115.010000
# 4       5/31/1980  1980   May          1            98.720000
# ...           ...   ...   ...        ...                  ...
# 10533  06/27/1989  1984   Aug          0           119.516531
# 10534  09/22/1988  1982   Nov          0                  NaN
# 10535  01/08/2002  2006   Jul          1            89.420249
# 10536  07/19/2018  2010   Sep          0           107.436484
# 10537  08/12/1991  2016   Sep          1           109.665827
#
#        Seasonality_Weight         Price  Advertising_Expenditure  Competition  \
# 0                0.500000  27483.571000                     1558            7
# ...

# %%
df.isna().sum()
# Out:
# Date                         0
# Year                         0
# Month                        0
# Recession                    0
# Consumer_Confidence        505
# Seasonality_Weight           0
# Price                      500
# Advertising_Expenditure      0
# Competition                  0
# GDP                          0
# Growth_Rate                  0
# unemployment_rate            0
# Automobile_Sales           505
# Vehicle_Type                 0
# City                         0
# dtype: int64
